# %% [markdown]
# # openmod Parse
#
# This notebook scrapes the [openmod-inititaive](https://wiki.openmod-initiative.org) database for all listed energy models.
#
# An earlier version of this notebook was published by Samuel Dotson for a [Ph.D. proposal](https://github.com/samgdotson/2023-dotson-prelim).

# %%
from lzma import MODE_NORMAL
from xml import dom
import requests
from lxml import etree
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
def has_no_class(tag):
    return not tag.has_attr('class')

# %%
URL = "https://wiki.openmod-initiative.org/wiki/Open_Models"
BASE_URL = "https://wiki.openmod-initiative.org"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

results = soup.find(id='mw-content-text')
list_elements = results.find_all('ul')

# %%
cols= ["institution",
    "doi",
    "citation",
    "computation time comments",
    "computation time minutes",
    "contact email",
    "contact persons",
    "data availability",
    "decisions",
    "deterministic",
    "full model name",
    "georegions",
    "georesolution",
    "is suited for many scenarios",
    "license",
    "math model type",
    "math model type shortdesc",
    "model class",
    "model source public",
    "modelling software",
    "open future",
    "open source licensed",
    "processing software",
    "report references",
    "sectors",
    "source download",
    "technologies",
    "text description",
    "time resolution",
    "website",
    "objective",
    "url",
    "authors",
    "example research questions",
    "math objective",
    "network coverage",
    "number of variables"]

# %%
model_list = list_elements[-1]

# run through the list of models

frames = []
for a in model_list.find_all('a', href=True):
    
    model_name = list(a.children)[0]
    print(model_name)

    # get the URL of a model
    MODEL_URL = BASE_URL + a['href']
    print(MODEL_URL)

    
    
    
    df_list = pd.read_html(MODEL_URL)
    
    obj = df_list[3].loc[4].values[1]
    
    large_df = df_list[4]
    large_df = large_df.rename(columns={1:f'{model_name}'}).T
    large_df.columns = large_df.iloc[0]
#     large_df.columns = cols
    large_df.drop(large_df.index[0], inplace=True)
    large_df['Objective'] = obj
    large_df['URL'] = MODEL_URL
    
    frames.append(large_df)
# Out:
# AMIRIS
# https://wiki.openmod-initiative.org/wiki/AMIRIS
# ASAM
# https://wiki.openmod-initiative.org/wiki/ASAM
# Antares-Simulator
# https://wiki.openmod-initiative.org/wiki/Antares-Simulator
# AnyMOD
# https://wiki.openmod-initiative.org/wiki/AnyMOD
# Backbone
# https://wiki.openmod-initiative.org/wiki/Backbone
# Balmorel
# https://wiki.openmod-initiative.org/wiki/Balmorel
# Breakthrough Energy Model
# https://wiki.openmod-initiative.org/wiki/Breakthrough_Energy_Model
# CAPOW
# https://wiki.openmod-initiative.org/wiki/CAPOW
# CESAR-P
# https://wiki.openmod-initiative.org/wiki/CESAR-P
# Calliope
# https://wiki.openmod-initiative.org/wiki/Calliope
# CapacityExpansion
# https://wiki.openmod-initiative.org/wiki/CapacityExpansion
# DESSTinEE
# https://wiki.openmod-initiative.org/wiki/DESSTinEE
# DIETER
# https://wiki.openmod-initiative.org/wiki/DIETER
# Demod
# https://wiki.openmod-initiative.org/wiki/Demod
# Dispa-SET
# https://wiki.openmod-initiative.org/wiki/Dispa-SET
# DynPP
# https://wiki.openmod-initiative.org/wiki/DynPP
# EA-PSM Electric Arc Flash
# https://wiki.openmod-initiative.org/wiki/EA-PSM_Electric_Arc_Flash
# EA-PSM Electric Short Circuit
# https://wiki.openmod-initiative.org/wiki/EA-PSM_Electric_Short_Circuit
# ELMOD
# https://wiki.openmod-initiative.org/wiki/ELMOD
# ELTRAMOD
# https://wiki.openmod-initiative.org/wiki/ELTRAMOD
# EMLab-Generation
# https://wiki.openmod-initiative.org/wiki/EMLab-Generation
# EMMA
# https://wiki.openmod-initiative.org/wiki/EMMA
# EOLES elec
# https://wiki.openmod-initiative.org/wiki/EOLES_elec
# EOLES elecRES
# https://wiki.openmod-initiative.org/wiki/EOLES_elecRES
# ESO-X
# https://wiki.openmod-initiative.org/wiki/ESO-X
# Energy Policy Simulator
# https://wiki.openmod-initiative.org/wiki/Energy_Policy_Simulator
# Energy Transition Model
# https://wiki.openmod-initiative.org/wiki/Energy_Transition_Model
# EnergyNumbers-Balancing
# https://wiki.openmod-initiative.org/wiki/EnergyNumbers-Balancing
# EnergyRt
# https://wiki.openmod-initiative.org/wiki/EnergyRt
# EnergyScope
# https://wiki.openmod-initiative.org/wiki/EnergyScope
# Ficus
# https://wiki.openmod-initiative.org/wiki/Ficus
# FlexiGIS
# https://wiki.openmod-initiative.org/wiki/FlexiGIS
# GAMAMOD
# https://wiki.openmod-initiative.org/wiki/GAMAMOD
# GAMAMOD-DE
# https://wiki.openmod-initiative.org/wiki/GAMAMOD-DE
# GRIMSEL-FLEX
# https://wiki.openmod-initiative.org/wiki/GRIMSEL-FLEX
# Genesys
# https://wiki.openmod-initiative.org/wiki/Genesys
# GridCal
# https://wiki.openmod-initiative.org/wiki/GridCal
# HighRES
# https://wiki.openmod-initiative.org/wiki/HighRES
# IRENA FlexTool
# https://wiki.openmod-initiative.org/wiki/IRENA_FlexTool
# JMM
# https://wiki.openmod-initiative.org/wiki/JMM
# Lemlab
# https://wiki.openmod-initiative.org/wiki/Lemlab
# LoadProfileGenerator
# https://wiki.openmod-initiative.org/wiki/LoadProfileGenerator
# MEDEAS
# https://wiki.openmod-initiative.org/wiki/MEDEAS
# MOCES
# https://wiki.openmod-initiative.org/wiki/MOCES
# Maon
# https://wiki.openmod-initiative.org/wiki/Maon
# Medea
# https://wiki.openmod-initiative.org/wiki/Medea
# MicroGridsPy
# https://wiki.openmod-initiative.org/wiki/MicroGridsPy
# Mosaik
# https://wiki.openmod-initiative.org/wiki/Mosaik
# MultiMod
# https://wiki.openmod-initiative.org/wiki/MultiMod
# NEMO
# https://wiki.openmod-initiative.org/wiki/NEMO
# NEMO (SEI)
# https://wiki.openmod-initiative.org/wiki/NEMO_(SEI)
# OMEGAlpes
# https://wiki.openmod-initiative.org/wiki/OMEGAlpes
# OSeMOSYS
# https://wiki.openmod-initiative.org/wiki/OSeMOSYS
# Oemof
# https://wiki.openmod-initiative.org/wiki/Oemof
# OnSSET
# https://wiki.openmod-initiative.org/wiki/OnSSET
# OpenTUMFlex
# https://wiki.openmod-initiative.org/wiki/OpenTUMFlex
# PLEXOS Open EU
# https://wiki.openmod-initiative.org/wiki/PLEXOS_Open_EU
# POMATO
# https://wiki.openmod-initiative.org/wiki/POMATO
# Pandapipes
# https://wiki.openmod-initiative.org/wiki/Pandapipes
# Pandapower
# https://wiki.openmod-initiative.org/wiki/Pandapower
# PowNet
# https://wiki.openmod-initiative.org/wiki/PowNet
# PowerMatcher
# https://wiki.openmod-initiative.org/wiki/PowerMatcher
# PowerSimulations.jl
# https://wiki.openmod-initiative.org/wiki/PowerSimulations.jl
# PowerSimulationsDynamics.jl
# https://wiki.openmod-initiative.org/wiki/PowerSimulationsDynamics.jl
# PowerSystems.jl
# https://wiki.openmod-initiative.org/wiki/PowerSystems.jl
# Pvlib python
# https://wiki.openmod-initiative.org/wiki/Pvlib_python
# PyLESA
# https://wiki.openmod-initiative.org/wiki/PyLESA
# PyPSA
# https://wiki.openmod-initiative.org/wiki/PyPSA
# QuaSi - GenSim
# https://wiki.openmod-initiative.org/wiki/QuaSi_-_GenSim
# QuaSi - ReSiE
# https://wiki.openmod-initiative.org/wiki/QuaSi_-_ReSiE
# REopt
# https://wiki.openmod-initiative.org/wiki/REopt
# Region4FLEX
# https://wiki.openmod-initiative.org/wiki/Region4FLEX
# Renpass
# https://wiki.openmod-initiative.org/wiki/Renpass
# SIREN
# https://wiki.openmod-initiative.org/wiki/SIREN
# SMS++
# https://wiki.openmod-initiative.org/wiki/SMS%2B%2B
# SciGRID gas
# https://wiki.openmod-initiative.org/wiki/SciGRID_gas
# SciGRID power
# https://wiki.openmod-initiative.org/wiki/SciGRID_power
# SimSEE
# https://wiki.openmod-initiative.org/wiki/SimSEE
# SimSES
# https://wiki.openmod-initiative.org/wiki/SimSES
# SpineOpt.jl
# https://wiki.openmod-initiative.org/wiki/SpineOpt.jl
# StELMOD
# https://wiki.openmod-initiative.org/wiki/StELMOD
# Switch
# https://wiki.openmod-initiative.org/wiki/Switch
# System Advisor Model (SAM)
# https://wiki.openmod-initiative.org/wiki/System_Advisor_Model_(SAM)
# TIMES
# https://wiki.openmod-initiative.org/wiki/TIMES
# TIMES Évora
# https://wiki.openmod-initiative.org/wiki/TIMES_%C3%89vora
# TIMES-PT
# https://wiki.openmod-initiative.org/wiki/TIMES-PT
# Temoa
# https://wiki.openmod-initiative.org/wiki/Temoa
# TransiEnt
# https://wiki.openmod-initiative.org/wiki/TransiEnt
# URBS
# https://wiki.openmod-initiative.org/wiki/URBS
# USENSYS
# https://wiki.openmod-initiative.org/wiki/USENSYS

# %%
model_df = pd.concat(frames, axis=0)
model_df.columns = cols
model_df.index.names = ['Model']

# %%
model_df.to_csv('results/esom_database_raw.csv', encoding='utf-8')

# %% [markdown]
# # Process Data
#
# * Filter for the frameworks that have open licenses AND have open source code.

# %%
model_df = pd.read_csv('results/esom_database_raw.csv', encoding='utf-8', index_col='Model')

# %%
model_df.fillna(str(-999), inplace=True)

# %%
print(f"The parser found {len(model_df.index)} distinct energy models on the openmod wiki.")
# Out:
# The parser found 90 distinct energy models on the openmod wiki.

# %%
strip_str = lambda x: x.strip(' +')
strip_series = lambda x: x.apply(strip_str)

# %%
clean_df = model_df.apply(strip_series)

# %%
clean_df[['objective','modelling software', 'processing software']]
# Out:
#                                                                                                                                     objective  \
# Model
# AMIRIS                                                                                                                                   -999
# ASAM                                                                                                                                     -999
# Antares-Simulator                                                          socio-economic welfare, investment costs, greenhouse gas emissions
# AnyMOD                                                                                 cost minimization by default, can set other objectives
# Backbone                                                                                            Cost minimization; emission minimization;
# Balmorel                                                                                                                       economic costs
# Breakthrough Energy Model                                                                                                       Minimize cost
# CAPOW                                                                                                                       Cost minimization
# CESAR-P                                                                                                                                  -999
# Calliope                                                                 User-dependent, including financial cost, CO2, and water consumption
# CapacityExpansion                                                                                                           Total system cost
# DESSTinEE                                                                                        Costs, welfare, carbon emissions, fuel mixes
# DIETER                                                                                                                      Cost minimization
# Demod                                                            Assess domestic energy demand evolution and demand-side-management scenarios
# Dispa-SET                                                                                                   Minimization of operational costs
# DynPP                                                                                              operation, cost, emissions, thermal stress
# EA-PSM Electric Arc Flash                                                                                                                -999
# EA-PSM Electric Short Circuit                                                                                                            -999
# ELMOD                                                                                                                                    -999
# ELTRAMOD                                                                                                   Minimization of total system costs
# EMLab-Generation                                                                                                                         -999
# EMMA                                                                                                                        Total system cost
# EOLES elec                                                            investment cost and operational costs (fixed and variable) minimization
# EOLES elecRES                                                         investment cost and operational costs (fixed and variable) minimization
# ESO-X                                                                                                              minimise total system cost
# Energy Policy Simulator                                                                                                                  -999
# Energy Transition Model                                Given demand and other choices, calculate primary energy use, costs, CO2-emission etc.
# EnergyNumbers-Balancing                                                                                                                  -999
# EnergyRt                                                                                                                                costs
# EnergyScope                                                                                        financial cost, greenhouse gases emissions
# Ficus                                                                                                                                   costs
# FlexiGIS                                    simualte local urban demand and supply, localise distributed storage, minimise total system costs
# GAMAMOD                                                                                                                                  -999
# GAMAMOD-DE                                                                                                                               -999
# GRIMSEL-FLEX                                                                                               Minimization of total system costs
# Genesys                                                                                                minimise levelised cost of electricity
# GridCal                                                                                          Match generation to demand and minimise cost
# HighRES                                                                                                    Minimization of total system costs
# IRENA FlexTool                                                                                                              cost minimization
# JMM                                                                                                                                      -999
# Lemlab                                                                                                                                   -999
# LoadProfileGenerator                                                                                                                     -999
# MEDEAS                                                                     CO2 equivalent emissions, energy, social, economic costs, RE-share
# MOCES                                                                                                                                    -999
# Maon                           Minimization of operational costs for electricity spot and frequency reserve markets considering emission caps
# Medea                                                                                                                       Total system cost
# MicroGridsPy                                                     Single or multi objective optimization (NPC, operation costs, CO2 emissions)
# Mosaik                                                                                                                                   -999
# MultiMod                                                                                                                                 -999
# NEMO                                                                                                     minimise average cost of electricity
# NEMO (SEI)                                                                                                    Minimize total discounted costs
# OMEGAlpes                                                                                                                                -999
# OSeMOSYS                                                                                             Minimise total discounted cost of system
# Oemof                                                                                                                        costs, emissions
# OnSSET                                                                                                                      Cost minimization
# OpenTUMFlex                                                                             Cost optimal optimization and flexibility calculation
# PLEXOS Open EU                                                                                                 Minimize total Generation cost
# POMATO                                                                                                                      Cost minimization
# Pandapipes                                                                                                                               -999
# Pandapower                                                                                                                               -999
# PowNet                                                                                                                      Cost minimization
# PowerMatcher                                                                                                                             -999
# PowerSimulations.jl                                                                                                                Least Cost
# PowerSimulationsDynamics.jl                                                                                                              -999
# PowerSystems.jl                                                                                                                          -999
# Pvlib python                                                                                                                             -999
# PyLESA                                                                                                      Minimization of operational costs
# PyPSA                                                                                                                       Cost minimization
# QuaSi - GenSim                                                                                                                           -999
# QuaSi - ReSiE                                                                                                                 energy balances
# REopt                                                                                                                 Minimize Lifecycle Cost
# Region4FLEX                                                                                                                              -999
# Renpass                                                                                                                        economic costs
# SIREN                                                                                            Match generation to demand and minimise cost
# SMS++                                                                                           in principle any, currently cost minimization
# SciGRID gas                                                                                                                              -999
# SciGRID power                                                                                                                            -999
# SimSEE                                                                                           minimization of the future operational cost.
# SimSES                                                                                                                                   -999
# SpineOpt.jl                                                                                                                 Cost minimization
# StELMOD                                                                                                 Minimization of total generation cost
# Switch                                                                         total cost or consumer surplus, including environmental adders
# System Advisor Model (SAM)                               time series power generation, installation cost, annual operating and financial cost
# TIMES                                                                                               Total discounted system cost minimisation
# TIMES Évora                                                                               Minimise total discounted cost of the energy system
# TIMES-PT                                                                                  Minimise total discounted cost of the energy system
# Temoa                                                                                                                       Cost minimization
# TransiEnt                                                                                                                                -999
# URBS                                                                                                 Minimise total discounted cost of system
# USENSYS                                                                                                                     Cost minimization
#
#                                                                                       modelling software  \
# Model
# AMIRIS                                                                                              Java
# ASAM                                                                                      Python (Pyomo)
# Antares-Simulator                                                                                 C++, C
# AnyMOD                                                                                        Julia/JuMP
# Backbone                                                                                            GAMS
# Balmorel                                                                                            GAMS
# Breakthrough Energy Model                                                                     Julia/JuMP
# CAPOW                                                                                     Python (Pyomo)
# CESAR-P                                                                               Python, EnergyPlus
# Calliope                                                                                  Python (Pyomo)
# CapacityExpansion                                                                             Julia/JuMP
# DESSTinEE                                                                                    Excel / VBA
# DIETER                                                                                       GAMS; CPLEX
# Demod                                                                                             Python
# Dispa-SET                                                                           Python (Pyomo), GAMS
# DynPP                                               Modelica, Dymola, (OpenModelica), C++, MySQL, SQLite
# EA-PSM Electric Arc Flash                                                                           Java
# EA-PSM Electric Short Circuit                                                                       Java
# ELMOD                                                                                               GAMS
# ELTRAMOD                                                                                     GAMS; CPLEX
# EMLab-Generation                                                                                    Java
# EMMA                                                                                                GAMS
# EOLES elec                                                                                          GAMS
# EOLES elecRES                                                                                       GAMS
# ESO-X                                                                                        GAMS; CPLEX
# Energy Policy Simulator                                                                           Vensim
# Energy Transition Model                                    Developed in-house written in Ruby (on Rails)
# EnergyNumbers-Balancing                                              Fortran, PHP, Javascript, HTML, CSS
# EnergyRt                                                                                      GAMS; GLPK
# EnergyScope                                                                    GLPK/GLPSOL or AMPL/Cplex
# Ficus                                                                                     Python (Pyomo)
# FlexiGIS                                                                                            -999
# GAMAMOD                                                                                             GAMS
# GAMAMOD-DE                                                                                   GAMS; CPLEX
# GRIMSEL-FLEX                                                                              Python (Pyomo)
# Genesys                        C++, boost library, MySQL and QT4, (optional CPLEX solver implementation)
# GridCal                                                                                           Python
# HighRES                                                                                      GAMS; CPLEX
# IRENA FlexTool                                                                              GNU MathProg
# JMM                                                                                                 -999
# Lemlab                                                                                     Python, Pyomo
# LoadProfileGenerator                                                                                  C#
# MEDEAS                                                                                            Phyton
# MOCES                                               Modelica, Dymola, (OpenModelica), C++, MySQL, SQLite
# Maon                                                                                                   C
# Medea                                                                                               GAMS
# MicroGridsPy                                                                              Python (Pyomo)
# Mosaik                                                                                            Python
# MultiMod                                                                                            GAMS
# NEMO                                                                                              Python
# NEMO (SEI)                                                                                         Julia
# OMEGAlpes                                                                                OMEGAlpes, PuLP
# OSeMOSYS                                                                                    GNU MathProg
# Oemof                                                                             Python, Pyomo, Coin-OR
# OnSSET                                                                                            Python
# OpenTUMFlex                                                                               Python (Pyomo)
# PLEXOS Open EU                                                                                    PLEXOS
# POMATO                                                                                        Julia/JuMP
# Pandapipes                                                                                        Python
# Pandapower                                                                                          -999
# PowNet                                                                                    Python (Pyomo)
# PowerMatcher                                                                                        Java
# PowerSimulations.jl                                                                                Julia
# PowerSimulationsDynamics.jl                                                                        Julia
# PowerSystems.jl                                                                                    Julia
# Pvlib python                                                                                      Python
# PyLESA                                                                                            Python
# PyPSA                                                                                      Python, Pyomo
# QuaSi - GenSim                                                    EnergyPlus, OpenStudio, MS Excel, Ruby
# QuaSi - ReSiE                                                                                      Julia
# REopt                                                                                         Julia/JuMP
# Region4FLEX                                                                                       Python
# Renpass                                                                                                R
# SIREN                                                                                   Python, NREL SAM
# SMS++                                                                                                SMS
# SciGRID gas                                                                                GeoJSON & CSV
# SciGRID power                                                                         Python, PostgreSQL
# SimSEE                                                                                        freepascal
# SimSES                                                                                            Python
# SpineOpt.jl                                                                                   Julia/JuMP
# StELMOD                                                                                             GAMS
# Switch                                                                                     Python, Pyomo
# System Advisor Model (SAM)                                                                C++, WxWidgets
# TIMES                                                                                               GAMS
# TIMES Évora                                                                                         GAMS
# TIMES-PT                                                                                            GAMS
# Temoa                                                                                     Python (Pyomo)
# TransiEnt                                                                                       Modelica
# URBS                                                                                      Python (Pyomo)
# USENSYS                                                                                       R/energyRt
#
#                                                                                                                               processing software
# Model
# AMIRIS                                                                                                                                     Python
# ASAM                                                                                                                          Python, PyPSA, Mesa
# Antares-Simulator                                                                                                              Python, TypeScript
# AnyMOD                                                                                                                                       -999
# Backbone                                                                                                                   Spine Toolbox or Excel
# Balmorel                                                                                                                                     -999
# Breakthrough Energy Model                                                                                                                  Python
# CAPOW                                                                                                                                        -999
# CESAR-P                                                                                                                                      -999
# Calliope                                                                                                                    Python (pandas et al)
# CapacityExpansion                                                                                                                           Julia
# DESSTinEE                                                                                                                             Excel / VBA
# DIETER                                                                                                                                   MS Excel
# Demod                                                                                                                                      Python
# Dispa-SET                                                                                                                                  Python
# DynPP                                                                                                                                      Matlab
# EA-PSM Electric Arc Flash                                                                                                            Java, JavaFX
# EA-PSM Electric Short Circuit                                                                                                        Java, JavaFX
# ELMOD                                                                                                                                        -999
# ELTRAMOD                                                                                                                                     -999
# EMLab-Generation                                                                                                                                R
# EMMA                                                                                                                                         -999
# EOLES elec                                                                                                                                   -999
# EOLES elecRES                                                                                                                                -999
# ESO-X                                                                                                                                           R
# Energy Policy Simulator                                                                                                                    Vensim
# Energy Transition Model                                                                                                               Excel / VBA
# EnergyNumbers-Balancing                                                                                                            Matlab, Python
# EnergyRt                                                                                                                                        R
# EnergyScope                                                                                                                                 Excel
# Ficus                                                                                                                       Python (pandas et al)
# FlexiGIS                                                                                                                                     -999
# GAMAMOD                                                                                                                                      -999
# GAMAMOD-DE                                                                                                                                   -999
# GRIMSEL-FLEX                                                                                                                Python (pandas et al)
# Genesys                                                                             Excel/Matlab and a Visualisation tool programmed in QT4 (c++)
# GridCal                                                                                                                                    Python
# HighRES                                                                                                                                    Python
# IRENA FlexTool                                                                                                                        Python, SQL
# JMM                                                                                                                                          -999
# Lemlab                                                                                                                       PostgreSQL, Ethereum
# LoadProfileGenerator                                                                                                                         -999
# MEDEAS                                                                                                                                     Phyton
# MOCES                                                                                                                               Lsodar, Dassl
# Maon                           Ansible, Ceph, cURL, Docker, GraphQL, Kubernetes, MinIO, MongoDB, Node.js, Preact, Python, TypeScript, WebAssembly
# Medea                                                                                                                                      Python
# MicroGridsPy                                                                                                                                Excel
# Mosaik                                                                                                                    HDF5, InfluxDB, Grafana
# MultiMod                                                                                                                      MS Access, MS Excel
# NEMO                                                                                                                                         -999
# NEMO (SEI)                                                                                                                                 SQLite
# OMEGAlpes                                                                                                                                    -999
# OSeMOSYS                                                                                                                                   Python
# Oemof                                                                                                                 Python, PostgreSQL, PostGIS
# OnSSET                                                                                                                                     Python
# OpenTUMFlex                                                                                                                                  -999
# PLEXOS Open EU                                                                                                                           MS Excel
# POMATO                                                                                                                                     Python
# Pandapipes                                                                                                                                   -999
# Pandapower                                                                                                                                   -999
# PowNet                                                                                                                                     Python
# PowerMatcher                                                                                                                                 -999
# PowerSimulations.jl                                                                                                                         Julia
# PowerSimulationsDynamics.jl                                                                                                                 Julia
# PowerSystems.jl                                                                                                                             Julia
# Pvlib python                                                                                                                        NumPy, Pandas
# PyLESA                                                                                                                                     Python
# PyPSA                                                                                                                                      Pandas
# QuaSi - GenSim                                                                                                                           MS Excel
# QuaSi - ReSiE                                                                                                                               Julia
# REopt                                                                                                                                      Python
# Region4FLEX                                                                                                                            PostgreSQL
# Renpass                                                                                                                        MySQL / R / RMySQL
# SIREN                                                                                                                                      Python
# SMS++                                                                                                                                hand-coded C
# SciGRID gas                                                                                                                                  -999
# SciGRID power                                                                                              Python, PostgreSQL, Osmosis, osm2pgsql
# SimSEE                                                                                                                                 freepascal
# SimSES                                                                                                                                     Python
# SpineOpt.jl                                                                                                                 Python, Spine Toolbox
# StELMOD                                                                                                                                  MS Excel
# Switch                                                                                                         Python, any user-selected software
# System Advisor Model (SAM)                                                                                                                   -999
# TIMES                                                                                                                         EXCEL, VEDA, ANSWER
# TIMES Évora                                                                                                                                  -999
# TIMES-PT                                                                                                                                     -999
# Temoa                                                                                                                                      SQLite
# TransiEnt                                                                                                                                  Dymola
# URBS                                                                                                                        Python (pandas et al)
# USENSYS                                                                                                                                         R

# %%
model_df.columns
# Out:
# Index(['institution', 'doi', 'citation', 'computation time comments',
#        'computation time minutes', 'contact email', 'contact persons',
#        'data availability', 'decisions', 'deterministic', 'full model name',
#        'georegions', 'georesolution', 'is suited for many scenarios',
#        'license', 'math model type', 'math model type shortdesc',
#        'model class', 'model source public', 'modelling software',
#        'open future', 'open source licensed', 'processing software',
#        'report references', 'sectors', 'source download', 'technologies',
#        'text description', 'time resolution', 'website', 'objective', 'url',
#        'authors', 'example research questions', 'math objective',
#        'network coverage', 'number of variables'],
#       dtype='object')

# %%
other_models = [
"REMix", # done
"PRIMES",  # added
"MARKAL", # deprecated, now TIMES
"METIS", # done
"ENSYSI",
"OSeMOSYS", #done
"SimREN", # EnergyPLAN
"NEMS", #done
"POLES",
"OPERA", #done
"EnergyPLAN", #done
"IWES",
"ESME", #done
"STREAM", # EnergyPLAN
"ETM", #done
"LEAP", # EnergyPLAN
"E4Cast", # EnergyPLAN
"DynEMo",
"IKARUS", # EnergyPLAN
]

# %%
has_openmod_entry = [(i in model_df.index) for i in other_models]
for m,b in zip(other_models, has_openmod_entry):
    print(m,b)
# Out:
# REMix False
# PRIMES False
# MARKAL False
# METIS False
# ENSYSI False
# OSeMOSYS True
# SimREN False
# NEMS False
# POLES False
# OPERA False
# EnergyPLAN False
# IWES False
# ESME False
# STREAM False
# ETM False
# LEAP False
# E4Cast False
# DynEMo False
# IKARUS False
